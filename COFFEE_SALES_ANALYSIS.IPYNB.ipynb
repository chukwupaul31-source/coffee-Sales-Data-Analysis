# %%
import pandas as pd

# %%
df = pd . read_csv ('coffee_sales_data_location2.csv')

# %%
df.head ()
# Out:
#         Date   Time    Coffee Type  Price Payment Type
# 0  4/26/2024  11:37       Espresso  145.7         Card
# 1  7/14/2024  19:43  Hot Chocolate  230.2         Card
# 2  1/29/2024  18:42       Espresso  145.7         Card
# 3   3/7/2024  10:21       Espresso  145.7         Card
# 4  2/20/2024  21:02          Latte  218.2         Cash

# %%
df.columns = df.columns. str.strip()
df
# Out:
#           Date   Time          Coffee Type  Price Payment Type
# 0    4/26/2024  11:37             Espresso  145.7         Card
# 1    7/14/2024  19:43        Hot Chocolate  230.2         Card
# 2    1/29/2024  18:42             Espresso  145.7         Card
# 3     3/7/2024  10:21             Espresso  145.7         Card
# 4    2/20/2024  21:02                Latte  218.2         Cash
# ..         ...    ...                  ...    ...          ...
# 995  7/10/2024  17:30  Americano with milk  202.8         Card
# 996  4/22/2024  11:59                Latte  218.2         Card
# 997   1/5/2024  11:29                Latte  218.2         Cash
# 998  1/13/2024  19:13              Cortado  172.0         Cash
# 999  1/12/2024  17:20  Americano with milk  202.8         Cash
#
# [1000 rows x 5 columns]

# %%
df.rename (columns={
    'Coffee Type':'Coffee_Type', 'Payment Type':'Payment_Type'
},inplace = True)
df
# Out:
#           Date   Time          Coffee_Type  Price Payment_Type
# 0    4/26/2024  11:37             Espresso  145.7         Card
# 1    7/14/2024  19:43        Hot Chocolate  230.2         Card
# 2    1/29/2024  18:42             Espresso  145.7         Card
# 3     3/7/2024  10:21             Espresso  145.7         Card
# 4    2/20/2024  21:02                Latte  218.2         Cash
# ..         ...    ...                  ...    ...          ...
# 995  7/10/2024  17:30  Americano with milk  202.8         Card
# 996  4/22/2024  11:59                Latte  218.2         Card
# 997   1/5/2024  11:29                Latte  218.2         Cash
# 998  1/13/2024  19:13              Cortado  172.0         Cash
# 999  1/12/2024  17:20  Americano with milk  202.8         Cash
#
# [1000 rows x 5 columns]

# %%
df['Time'] = pd. to_datetime (df['Time'],errors='coerce')
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type
# 0    4/26/2024 2025-10-08 11:37:00             Espresso  145.7         Card
# 1    7/14/2024 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2    1/29/2024 2025-10-08 18:42:00             Espresso  145.7         Card
# 3     3/7/2024 2025-10-08 10:21:00             Espresso  145.7         Card
# 4    2/20/2024 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995  7/10/2024 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996  4/22/2024 2025-10-08 11:59:00                Latte  218.2         Card
# 997   1/5/2024 2025-10-08 11:29:00                Latte  218.2         Cash
# 998  1/13/2024 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999  1/12/2024 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
# [1000 rows x 5 columns]

# %%
df.reset_index (drop= True, inplace =True)
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type
# 0    4/26/2024 2025-10-08 11:37:00             Espresso  145.7         Card
# 1    7/14/2024 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2    1/29/2024 2025-10-08 18:42:00             Espresso  145.7         Card
# 3     3/7/2024 2025-10-08 10:21:00             Espresso  145.7         Card
# 4    2/20/2024 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995  7/10/2024 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996  4/22/2024 2025-10-08 11:59:00                Latte  218.2         Card
# 997   1/5/2024 2025-10-08 11:29:00                Latte  218.2         Cash
# 998  1/13/2024 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999  1/12/2024 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
# [1000 rows x 5 columns]

# %%
# converting price to numeric

# %%
df['Price'] = pd.to_numeric (df['Price'],errors = 'coerce')
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type
# 0    4/26/2024 2025-10-08 11:37:00             Espresso  145.7         Card
# 1    7/14/2024 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2    1/29/2024 2025-10-08 18:42:00             Espresso  145.7         Card
# 3     3/7/2024 2025-10-08 10:21:00             Espresso  145.7         Card
# 4    2/20/2024 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995  7/10/2024 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996  4/22/2024 2025-10-08 11:59:00                Latte  218.2         Card
# 997   1/5/2024 2025-10-08 11:29:00                Latte  218.2         Cash
# 998  1/13/2024 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999  1/12/2024 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
# [1000 rows x 5 columns]

# %%
# checking for null values

# %%
print(df.isnull().sum())
# Out:
# Date            0
# Time            0
# Coffee_Type     0
# Price           0
# Payment_Type    0
# dtype: int64

# %%
# converting date and time to date time

# %%
df ['Date'] = pd.to_datetime (df['Date'])
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
df ['Time'] =pd.to_datetime  (df['Time'], format ='%h:%m:%s')
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
# creating a new column

# %%
df['Day'] = df ['Date']. dt.day_name()
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
# getting mondat, Tuesday

# %%
df['Month']  =  df['Date'].dt.month_name()
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
# january, and february

# %%
df['Hour'] = pd.to_datetime (df['Time'], format = '%h:%m:%s').dt.hour
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
# Total Sales

# %%
total_sales = df['Price'].sum()
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
# sales by coffee type using groupby and aggregate function

# %%
group_by_dataframe= df.groupby ('Coffee_Type')
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
df.groupby ('Coffee_Type'). sum()
# Out:
#                        Price  Hour
# Coffee_Type
# Americano            20542.8  1856
# Americano with milk  26972.4  2111
# Cappuccino           29108.2  2034
# Cocoa                29537.5  1957
# Cortado              22704.0  2070
# Espresso             17775.4  1899
# Hot Chocolate        29926.0  1969
# Latte                24656.6  1759

# %%
df.groupby ('Coffee_Type'). max()
# Out:
#                           Date                Time  Price Payment_Type  \
# Coffee_Type
# Americano           2024-07-12 2025-10-08 21:30:00  180.2         Cash
# Americano with milk 2024-07-14 2025-10-08 21:26:00  202.8         Cash
# Cappuccino          2024-07-13 2025-10-08 21:28:00  222.2         Cash
# Cocoa               2024-07-15 2025-10-08 21:28:00  236.3         Cash
# Cortado             2024-07-14 2025-10-08 21:29:00  172.0         Cash
# Espresso            2024-07-15 2025-10-08 21:30:00  145.7         Cash
# Hot Chocolate       2024-07-15 2025-10-08 21:29:00  230.2         Cash
# Latte               2024-07-15 2025-10-08 21:29:00  218.2         Cash
#
#                            Day Month  Hour
# Coffee_Type
# Americano            Wednesday   May    21
# Americano with milk  Wednesday   May    21
# Cappuccino           Wednesday   May    21
# Cocoa                Wednesday   May    21
# Cortado              Wednesday   May    21
# ...

# %%
df.groupby ('Coffee_Type').mean()
# Out:
#                      Price       Hour
# Coffee_Type
# Americano            180.2  16.280702
# Americano with milk  202.8  15.872180
# Cappuccino           222.2  15.526718
# Cocoa                236.3  15.656000
# Cortado              172.0  15.681818
# Espresso             145.7  15.565574
# Hot Chocolate        230.2  15.146154
# Latte                218.2  15.566372

# %%
df.groupby ('Coffee_Type'). count()
# Out:
#                      Date  Time  Price  Payment_Type  Day  Month  Hour
# Coffee_Type
# Americano             114   114    114           114  114    114   114
# Americano with milk   133   133    133           133  133    133   133
# Cappuccino            131   131    131           131  131    131   131
# Cocoa                 125   125    125           125  125    125   125
# Cortado               132   132    132           132  132    132   132
# Espresso              122   122    122           122  122    122   122
# Hot Chocolate         130   130    130           130  130    130   130
# Latte                 113   113    113           113  113    113   113

# %%
sales by day of week

# %%
sales_by_day = df .groupby ('Day') ['Price'].sum()
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
# sales by hour

# %%
sales_by_day = df .groupby ('Hour') ['Price'].sum().sort_values(ascending =False)
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
sales_by_type = df.groupby ('Coffee_Type') ['Price']. sum().sort_values (ascending= False)
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
df.reset_index (drop= True, inplace =True)
df
# Out:
#           Date                Time          Coffee_Type  Price Payment_Type  \
# 0   2024-04-26 2025-10-08 11:37:00             Espresso  145.7         Card
# 1   2024-07-14 2025-10-08 19:43:00        Hot Chocolate  230.2         Card
# 2   2024-01-29 2025-10-08 18:42:00             Espresso  145.7         Card
# 3   2024-03-07 2025-10-08 10:21:00             Espresso  145.7         Card
# 4   2024-02-20 2025-10-08 21:02:00                Latte  218.2         Cash
# ..         ...                 ...                  ...    ...          ...
# 995 2024-07-10 2025-10-08 17:30:00  Americano with milk  202.8         Card
# 996 2024-04-22 2025-10-08 11:59:00                Latte  218.2         Card
# 997 2024-01-05 2025-10-08 11:29:00                Latte  218.2         Cash
# 998 2024-01-13 2025-10-08 19:13:00              Cortado  172.0         Cash
# 999 2024-01-12 2025-10-08 17:20:00  Americano with milk  202.8         Cash
#
#            Day     Month  Hour
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=sales_by_type.index, y=sales_by_type.values)
plt.title("Total Sales by Coffee Type")
plt.ylabel("Total Sales ($)")
plt.xlabel("Coffee Type")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=sales_by_day.index, y=sales_by_day.values)
plt.title("Total Sales by Day of the Week")
plt.ylabel("Total Sales ($)")
plt.xlabel("Day")
plt.show()

# %%
sales_by_hour = df.groupby('Hour')['Price'].sum()

plt.figure(figsize=(8,5))
sns.lineplot(x=sales_by_hour.index, y=sales_by_hour.values, marker='o')
plt.title("Hourly Sales Trend")
plt.xlabel("Hour of the Day")
plt.ylabel("Total Sales ($)")
plt.show()

# %%
sales_by_type = df.groupby('Coffee_Type')['Price'].sum().sort_values(ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(x=sales_by_type.index, y=sales_by_type.values)
plt.title("Total Sales by Coffee Type")
plt.xlabel("Coffee_Type")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=45)
plt.show()

# %%
payment_share = df.groupby('Payment_Type')['Price'].sum().sort_values(ascending=False)

plt.figure(figsize=(6,6))
plt.pie(payment_share, labels=payment_share.index, autopct='%1.1f%%')
plt.title("Payment Method Share")
plt.show()

# %%
sales_by_month = df.groupby('Month')['Price'].sum()

plt.figure(figsize=(8,5))
sns.barplot(x=sales_by_month.index, y=sales_by_month.values)
plt.title("Total Sales by Month")
plt.xlabel("Month")
plt.ylabel("Total Sales ($)")
plt.show()

# %%
sales_by_day = df.groupby('Day')['Price'].sum()

plt.figure(figsize=(8,5))
sns.barplot(x=sales_by_day.index, y=sales_by_day.values)
plt.title("Sales by Day of the Week")
plt.xlabel("Day")
plt.ylabel("Total Sales ($)")
plt.show()

# %%
CHUKWU PAUM CHIEMERIE
